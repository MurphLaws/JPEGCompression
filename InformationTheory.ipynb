# %%
import numpy as np
import matplotlib.pyplot as plt


p = np.linspace(0,1,1000)
y = -p*np.log2(p)-(1-p)*np.log2(1-p)

plt.plot(p,y)
# Out:
# /tmp/ipykernel_22934/1364379049.py:6: RuntimeWarning: divide by zero encountered in log2
#   y = -p*np.log2(p)-(1-p)*np.log2(1-p)
# /tmp/ipykernel_22934/1364379049.py:6: RuntimeWarning: invalid value encountered in multiply
#   y = -p*np.log2(p)-(1-p)*np.log2(1-p)
